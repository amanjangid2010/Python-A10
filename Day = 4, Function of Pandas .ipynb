# %%
import pandas as pd

# %%
a = pd.read_csv("placement - placement.csv")
a
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
a.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
a.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
a.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_a = a.iloc[:4, :3]
top_left_corner_a
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
a.loc[1:3,["cgpa","placed"]]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p = a.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = a.empty
b
# Out:
# False

# %%
a.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
a = a.dropna()

# %%
i = a.ndim  # number of axes (it is 2 )
i
# Out:
# 2

# %%
t = a.shape # shape = n(rows), n(columns)
t
# Out:
# (100, 3)

# %%
d = a.size 
d
# Out:
# 300

# %%
df = a.values # get a numpy array for df
df
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = a.copy()

# %%
p = a.sort_values(by = "resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = a.astype(int)   # type conversion
a["cgpa"] = a["cgpa"].astype(int)
a
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
a["resume_score"] = a["resume_score"].astype(int)
a
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
a["cgpa"] = a["cgpa"].add(4)
a
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
a = a.drop(columns = ['cga'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[262], line 1
# ----> 1 a = a.drop(columns = ['cga'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
a
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
s = a.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = a.max()
p
# Out:
# cgpa            13
# resume_score     9
# placed           1
# dtype: int64

# %%
q = a.min()
q
# Out:
# cgpa            9
# resume_score    4
# placed          0
# dtype: int64

# %%
r = a["cgpa"].mean()
r
# Out:
# 10.47

# %%
s = a["cgpa"].median()
s
# Out:
# 10.0

# %%
a.mean()
# Out:
# cgpa            10.47
# resume_score     6.47
# placed           0.50
# dtype: float64

# %%
a.median()
# Out:
# cgpa            10.0
# resume_score     7.0
# placed           0.5
# dtype: float64

# %%
s = a.sum()
s
# Out:
# cgpa            1047
# resume_score     647
# placed            50
# dtype: int64

# %%
g = a.filter(items = ["cgpa" , "placed"])
g
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
## df[["cgpa", "placed"]] # second option of filtering

# %%
s = a.filter(items = [5,6] , axis = 0) # axis = 0  means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    12             6       1
# 6     9             7       0

# %%
s = a.to_dict() # save in dictionary
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
q = a.to_string() # save in string
q
# Out:
# '    cgpa  resume_score  placed\n0     12             6       1\n1     10             5       0\n2     12             8       1\n3     10             7       1\n4     11             7       1\n5     12             6       1\n6      9             7       0\n7     10             6       0\n8     10             6       0\n9     11             7       1\n10    10             6       0\n11     9             6       0\n12    10             7       0\n13    12             5       1\n14    11             6       1\n15    12             5       1\n16    12             7       1\n17    11             8       1\n18     9             5       0\n19    10             8       1\n20     9             8       0\n21    10             7       0\n22    10             5       0\n23    10             7       0\n24    12             6       1\n25    11             5       1\n26    10             6       0\n27     9             6       0\n28    11             7       1\n29    10             7       0\n30   
# ...

# %%
e = a.to_csv("path_location")

# %%
idx = a.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = a.columns[0] # first colum label
label
# Out:
# 'cgpa'

# %%
p = a.columns.tolist() # list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = a.columns.values # array of column labels
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = a.rename(columns = {"cgpa":"updated_cgpa",
                        "resume_score":"semester_marks"})  # how to rename a column
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             12               6       1
# 1             10               5       0
# 2             12               8       1
# 3             10               7       1
# 4             11               7       1
# ..           ...             ...     ...
# 95            10               6       0
# 96            12               7       1
# 97            10               7       0
# 98            12               5       1
# 99            10               6       0
#
# [100 rows x 3 columns]

# %%
a["Cgpan"] = a["cgpa"].astype(int)

# %%
a
# Out:
#     cgpa  resume_score  placed  Cgpan
# 0     12             6       1     12
# 1     10             5       0     10
# 2     12             8       1     12
# 3     10             7       1     10
# 4     11             7       1     11
# ..   ...           ...     ...    ...
# 95    10             6       0     10
# 96    12             7       1     12
# 97    10             7       0     10
# 98    12             5       1     12
# 99    10             6       0     10
#
# [100 rows x 4 columns]

# %%
s = a.drop(columns = ["Cgpan"])  # colum delete karne ke liy
s
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
a["New"] = a["cgpa"].where(a["cgpa"]>10 , other = 0)

# %%
a.sample(12)
# Out:
#     cgpa  resume_score  placed  Cgpan  New
# 5     12             6       1     12   12
# 41    12             5       1     12   12
# 8     10             6       0     10    0
# 44     9             5       0      9    0
# 31     9             7       0      9    0
# 57    10             7       0     10    0
# 32     9             7       0      9    0
# 89     9             7       0      9    0
# 10    10             6       0     10    0
# 75    10             7       1     10    0
# 33    12             7       1     12   12
# 87     9             5       0      9    0

# %%
# data frame merging, contenating

# %%
data1 = {
    "name": ["Sally","Mary","John"],
    "age": [50,40,30]
}

data2 = {
    "name": ["Sally", "Peter", "Micky"],
    "age": [77,44,22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = df1.merge(df2, how="right")

# %%
newdf
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %%
newdf = df1.merge(df2, how="left")

# %%
newdf
# Out:
#     name  age
# 0  Sally   50
# 1   Mary   40
# 2   John   30

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
new_dt = pd.concat([df1,df2])
new_dt
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
df=pd.merge(df1,df2, on = "Address", how="inner")
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12            Bcom
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52          B.hons

# %%
# covid wala data main city wale colume
# jitne city hai ==  df["gender"].value_counts() ===  df["city"].value_counts()
